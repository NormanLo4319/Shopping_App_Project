# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

import keras
from keras.preprocessing import image
from keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)
# Out:
# Using TensorFlow backend.

# %%
# Load the Xception model
# https://keras.io/applications/#xception
model = Xception(include_top=True, weights='imagenet')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 18:48:39.641928 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 18:48:39.660709 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 18:48:39.663510 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0717 18:48:39.687371 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0717 18:48:39.688170 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0717 18:48:39.712623 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0717 18:48:40.117016 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# Default Image Size for Xception
image_size = (299, 299)

# %% [markdown]
# # Asparagus Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "asparagus5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n03461385', 'grocery_store', 0.66150296), ('n07718472', 'cucumber', 0.16066016), ('n07753592', 'banana', 0.039340034)]]

# %%
# Refactor above steps into reusable function
#def predict(image_path):
#    img = image.load_img(image_path, target_size=image_size)
#    x = image.img_to_array(img)
#    x = np.expand_dims(x, axis=0)
#    x = preprocess_input(x)
#    predictions = model.predict(x)
#    plt.imshow(img)
#    print('Predicted:', decode_predictions(predictions, top=3))

# %%
# Predict labels for new image
#image_path = os.path.join("..", "Images", "kitten.jpg")

# %% [markdown]
# # Avocado Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "avocado5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07753113', 'fig', 0.2199823), ('n07749582', 'lemon', 0.09968431), ('n03461385', 'grocery_store', 0.08726249)]]

# %% [markdown]
# # Beets Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "beets3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07720875', 'bell_pepper', 0.22561663), ('n07718472', 'cucumber', 0.113351405), ('n07753113', 'fig', 0.071705736)]]

# %% [markdown]
# # Broccoli Test   Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "broccoli2.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714990', 'broccoli', 0.98925614), ('n07715103', 'cauliflower', 0.0014170702), ('n04596742', 'wok', 0.0003229084)]]

# %% [markdown]
# # Cabbage Test  Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "cabbage3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714571', 'head_cabbage', 0.8654153), ('n07749582', 'lemon', 0.002364824), ('n07715103', 'cauliflower', 0.0022140106)]]

# %% [markdown]
# # Carrot Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "carrots5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n03461385', 'grocery_store', 0.19274996), ('n07718472', 'cucumber', 0.18596137), ('n07716358', 'zucchini', 0.087235965)]]

# %% [markdown]
# # Celery Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "celery5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07716358', 'zucchini', 0.6974789), ('n07714990', 'broccoli', 0.08120855), ('n13133613', 'ear', 0.06189429)]]

# %% [markdown]
# # Chinese Cabbage Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "chinese_cabbage5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714571', 'head_cabbage', 0.9856064), ('n07715103', 'cauliflower', 0.0022125433), ('n07684084', 'French_loaf', 0.0008475303)]]

# %% [markdown]
# # Cucumber Test   Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "cucumber2.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07718472', 'cucumber', 0.9385745), ('n07716358', 'zucchini', 0.036045674), ('n07720875', 'bell_pepper', 0.0006114714)]]

# %% [markdown]
# # Eggplant Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "eggplant4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07720875', 'bell_pepper', 0.40714234), ('n07716358', 'zucchini', 0.24650197), ('n07718472', 'cucumber', 0.21636926)]]

# %% [markdown]
# # Green Beans Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "green_beans.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n02526121', 'eel', 0.28548852), ('n07718472', 'cucumber', 0.101224706), ('n03804744', 'nail', 0.054913674)]]

# %% [markdown]
# # Lose Beets Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "lose_beets2.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07768694', 'pomegranate', 0.31008086), ('n07753113', 'fig', 0.16414474), ('n12768682', 'buckeye', 0.072704665)]]

# %% [markdown]
# # Mushrooms Test      Only works for white mushrooms, not other color mushrooms

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "mushrooms2.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07734744', 'mushroom', 0.6058218), ('n13052670', 'hen-of-the-woods', 0.30194226), ('n12985857', 'coral_fungus', 0.016396483)]]

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "mushrooms5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n13044778', 'earthstar', 0.06874743), ('n12768682', 'buckeye', 0.05868103), ('n13052670', 'hen-of-the-woods', 0.03122611)]]

# %% [markdown]
# # Okra Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "okra3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07716358', 'zucchini', 0.64590275), ('n13133613', 'ear', 0.03890371), ('n07718472', 'cucumber', 0.016392207)]]

# %% [markdown]
# # Potato Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "potato4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07768694', 'pomegranate', 0.79141855), ('n03461385', 'grocery_store', 0.038208667), ('n07745940', 'strawberry', 0.0187653)]]

# %% [markdown]
# # Radicchio Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "radicchio3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714571', 'head_cabbage', 0.17847313), ('n07753113', 'fig', 0.076439746), ('n12768682', 'buckeye', 0.04837727)]]

# %% [markdown]
# # Radishes Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "radishes1.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n12620546', 'hip', 0.6151235), ('n03720891', 'maraca', 0.06413109), ('n03461385', 'grocery_store', 0.011496177)]]

# %% [markdown]
# # Sprouts Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "sprouts4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714571', 'head_cabbage', 0.80069387), ('n07753113', 'fig', 0.0063054836), ('n07715103', 'cauliflower', 0.005633606)]]

# %% [markdown]
# # Sweet Potato Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "sweet_potato4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n03461385', 'grocery_store', 0.14741112), ('n07718472', 'cucumber', 0.10500583), ('n02927161', 'butcher_shop', 0.06383949)]]

# %% [markdown]
# # Squash Test    Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "squash4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07717556', 'butternut_squash', 0.85285944), ('n07716906', 'spaghetti_squash', 0.025405103), ('n07717410', 'acorn_squash', 0.004409706)]]

# %% [markdown]
# # Tomato Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "tomato4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07720875', 'bell_pepper', 0.28851563), ('n03461385', 'grocery_store', 0.20495975), ('n07718472', 'cucumber', 0.17529014)]]

# %% [markdown]
# # Zucchini Test   Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "zucchini5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07716358', 'zucchini', 0.8946002), ('n07716906', 'spaghetti_squash', 0.00962167), ('n07718472', 'cucumber', 0.003949889)]]
