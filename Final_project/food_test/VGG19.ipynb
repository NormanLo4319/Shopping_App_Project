# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

import keras
from keras.preprocessing import image
from keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)
# Out:
# Using TensorFlow backend.

# %%
# Load the VGG19 model
# https://keras.io/applications/#VGG19
model = VGG19(include_top=True, weights='imagenet')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0724 11:25:48.747791 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0724 11:25:48.771685 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0724 11:25:48.776167 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0724 11:25:48.825648 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0724 11:25:50.873248 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0724 11:25:50.874250 140735799436160 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
# Define default image size for VGG19
image_size = (224, 224)

# %% [markdown]
# # AsparagusTest

# %%
# Load the image and resize to default image size (run image1-5)
image_path = os.path.join("test_images", "asparagus3.jpg")
img = image.load_img(image_path, target_size=image_size)

# Preprocess image for model prediction
# This step handles scaling and normalization for VGG19
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07718472', 'cucumber', 0.11743599), ('n07753592', 'banana', 0.10494147), ('n07716358', 'zucchini', 0.0797032)]]

# %% [markdown]
# # Avocado Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "avocado4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07716358', 'zucchini', 0.1640893), ('n07718472', 'cucumber', 0.09214909), ('n03461385', 'grocery_store', 0.08681247)]]

# %% [markdown]
# # Beets Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "beets3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07768694', 'pomegranate', 0.24645492), ('n12620546', 'hip', 0.14241493), ('n07753113', 'fig', 0.1365729)]]

# %% [markdown]
# # Broccoli Test Good Prediction¶

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "broccoli1.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714990', 'broccoli', 0.9929554), ('n07715103', 'cauliflower', 0.007008074), ('n07714571', 'head_cabbage', 2.9764265e-05)]]

# %% [markdown]
# # Cabbage Test Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "cabbage3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714571', 'head_cabbage', 0.99999416), ('n07715103', 'cauliflower', 4.0443947e-06), ('n03958227', 'plastic_bag', 9.561676e-07)]]

# %% [markdown]
# # Carrot Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "carrots1.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n03884397', 'panpipe', 0.7245231), ('n02906734', 'broom', 0.028585432), ('n03372029', 'flute', 0.025745014)]]

# %% [markdown]
# # Celery Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "celery5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07716358', 'zucchini', 0.4692252), ('n07718472', 'cucumber', 0.21387476), ('n13133613', 'ear', 0.11424366)]]

# %% [markdown]
# # Chinese Cabbage Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "chinese_cabbage5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714571', 'head_cabbage', 0.97104836), ('n07715103', 'cauliflower', 0.011674481), ('n07718472', 'cucumber', 0.009277647)]]

# %% [markdown]
# # Cucumber Test Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "cucumber4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07718472', 'cucumber', 0.9952213), ('n07716358', 'zucchini', 0.0047744364), ('n07720875', 'bell_pepper', 2.5059426e-06)]]

# %% [markdown]
# # Eggplant Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "eggplant4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07718472', 'cucumber', 0.46331567), ('n07716358', 'zucchini', 0.22256878), ('n07720875', 'bell_pepper', 0.06376453)]]

# %% [markdown]
# # Green Beans Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "green_beans.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n01930112', 'nematode', 0.2293469), ('n07831146', 'carbonara', 0.20378645), ('n04596742', 'wok', 0.056623433)]]

# %% [markdown]
# # Lose Beets Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "lose_beets2.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n12768682', 'buckeye', 0.52389175), ('n07768694', 'pomegranate', 0.32272586), ('n07753113', 'fig', 0.06794003)]]

# %% [markdown]
# # Mushrooms Test Only works for white mushrooms, not other color mushrooms

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "mushrooms2.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07734744', 'mushroom', 0.36424458), ('n13052670', 'hen-of-the-woods', 0.1231565), ('n13054560', 'bolete', 0.051045757)]]

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "mushrooms7.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n12267677', 'acorn', 0.54523486), ('n13044778', 'earthstar', 0.16526277), ('n07734744', 'mushroom', 0.083121374)]]

# %% [markdown]
# # Okra Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "okra3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07716358', 'zucchini', 0.96826005), ('n07718472', 'cucumber', 0.017092329), ('n13133613', 'ear', 0.004952359)]]

# %% [markdown]
# # Potato Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "potato4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07768694', 'pomegranate', 0.93887746), ('n03461385', 'grocery_store', 0.027885405), ('n07717556', 'butternut_squash', 0.007053198)]]

# %% [markdown]
# # Radicchio Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "radicchio3.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07714571', 'head_cabbage', 0.41453367), ('n13054560', 'bolete', 0.2170683), ('n07718747', 'artichoke', 0.08247112)]]

# %% [markdown]
# # Radishes Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "radishes1.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n12620546', 'hip', 0.6163128), ('n07768694', 'pomegranate', 0.22177021), ('n07745940', 'strawberry', 0.040853925)]]

# %% [markdown]
# # Sprouts Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "sprouts4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07718472', 'cucumber', 0.757142), ('n07714571', 'head_cabbage', 0.12965259), ('n07717410', 'acorn_squash', 0.031640746)]]

# %% [markdown]
# # Sweet Potato Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "sweet_potato4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n02321529', 'sea_cucumber', 0.11737115), ('n07860988', 'dough', 0.106382705), ('n02395406', 'hog', 0.10393466)]]

# %% [markdown]
# # Squash Test Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "squash4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07717556', 'butternut_squash', 0.99775773), ('n07716906', 'spaghetti_squash', 0.001744694), ('n07734744', 'mushroom', 0.00018064454)]]

# %% [markdown]
# # Tomato Test

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "tomato4.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n03461385', 'grocery_store', 0.33026862), ('n12620546', 'hip', 0.25544995), ('n07718472', 'cucumber', 0.16764532)]]

# %% [markdown]
# # Zucchini Test Good Prediction

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("test_images", "zucchini5.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n07716358', 'zucchini', 0.98784745), ('n07718472', 'cucumber', 0.0094046), ('n07716906', 'spaghetti_squash', 0.0017109647)]]
